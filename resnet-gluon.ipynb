# %%
# ResNet：深度残差网络
# http://zh.gluon.ai/chapter_convolutional-neural-networks/resnet-gluon.html

from mxnet.gluon import nn
from mxnet import nd

class Residual(nn.Block):
    def __init__(self, channels, same_shape=True, **kwargs):
        super(Residual, self).__init__(**kwargs)
        self.same_shape = same_shape
        strides = 1 if same_shape else 2
        self.conv1 = nn.Conv2D(channels, kernel_size=3, padding=1,
                              strides=strides)
        self.bn1 = nn.BatchNorm()
        self.conv2 = nn.Conv2D(channels, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm()
        if not same_shape:
            self.conv3 = nn.Conv2D(channels, kernel_size=1,
                                  strides=strides)
    
    def forward(self, x):
#         print('same in / out shape:', self.same_shape)
#         print('x.shape:', x.shape)
        out = nd.relu(self.bn1(self.conv1(x)))
#         print(out.shape)
        out = self.bn2(self.conv2(out))
#         print(out.shape)
        if not self.same_shape:
            x = self.conv3(x)
#             print('x.shape:',x.shape)
        return nd.relu(out + x)
# Out:
# /home/ly/anaconda3/envs/learning/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 输入输出通道相同
blk = Residual(3)
blk.initialize()

x = nd.random.uniform(shape=(4,3,96,96))
y = blk(x)
print(y.shape)
print(blk)
# Out:
# (4, 3, 96, 96)
# Residual(
#   (conv1): Conv2D(3 -> 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=3)
#   (conv2): Conv2D(3 -> 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=3)
# )

# %%
# 输入输出通道不同
blk2 = Residual(8, same_shape=False)
blk2.initialize()
y2 = blk2(x)
print(y2.shape)
print(blk2)
# Out:
# (4, 8, 48, 48)
# Residual(
#   (conv1): Conv2D(3 -> 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=8)
#   (conv2): Conv2D(8 -> 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=8)
#   (conv3): Conv2D(3 -> 8, kernel_size=(1, 1), stride=(2, 2))
# )

# %%
# 构建ResNet
class ResNet(nn.Block):
    def __init__(self, num_classes, verbose=False, **kwargs):
        super(ResNet, self).__init__(**kwargs)
        self.verbose = verbose
        # add name_scope on the outermost Sequential
        with self.name_scope():
            # block 1
            b1 = nn.Conv2D(64, kernel_size=7, strides=2)
            # block 2
            b2 = nn.Sequential()
            b2.add(
                nn.MaxPool2D(pool_size=3, strides=2),
                Residual(64),
                Residual(64)
            )
            # block 3
            b3 = nn.Sequential()
            b3.add(
                Residual(128, same_shape=False),
                Residual(128)
            )
            # block 4
            b4 = nn.Sequential()
            b4.add(
                Residual(256, same_shape=False),
                Residual(256)
            )
            # block 5
            b5 = nn.Sequential()
            b5.add(
                Residual(512, same_shape=False),
                Residual(512)
            )
            # block 6
            b6 = nn.Sequential()
            b6.add(
                nn.AvgPool2D(pool_size=3),
                nn.Dense(num_classes)
            )
            # chain all blocks together
            self.net = nn.Sequential()
            self.net.add(b1, b2, b3, b4, b5, b6)
    
    def forward(self, x):
        out = x
        for i, b in enumerate(self.net):
            out = b(out)
            if self.verbose:
                print('Block %d output: %s' % (i+1, out.shape))
        return out

# %%
net = ResNet(10, verbose=True)
net.initialize()

x = nd.random.uniform(shape=(4,3,96, 96))
y = net(x)
print(net)
# Out:
# Block 1 output: (4, 64, 45, 45)
# Block 2 output: (4, 64, 22, 22)
# Block 3 output: (4, 128, 11, 11)
# Block 4 output: (4, 256, 6, 6)
# Block 5 output: (4, 512, 3, 3)
# Block 6 output: (4, 10)
# ResNet(
#   (net): Sequential(
#     (0): Conv2D(3 -> 64, kernel_size=(7, 7), stride=(2, 2))
#     (1): Sequential(
#       (0): MaxPool2D(size=(3, 3), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#       (1): Residual(
#         (conv1): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#         (conv2): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#       )
#       (2): Residual(
#         (conv1): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#         (conv2): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#       )
#     )
#     (2): Sequential(
#       (0): Residual(
#         (conv1): Conv2D(64 -> 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#         (conv2): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#         (conv3): Conv2D(64 -> 128, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (1): Residual(
#         (conv1): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#         (conv2): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#       )
#     )
#     (3): Sequential(
#       (0): Residual(
#         (conv1): Conv2D(128 -> 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=256)
#         (conv2): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=256)
#         (conv3): Conv2D(128 -> 256, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (1): Residual(
#         (conv1): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=256)
#         (conv2): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=256)
#       )
#     )
#     (4): Sequential(
#       (0): Residual(
#         (conv1): Conv2D(256 -> 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=512)
#         (conv2): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=512)
#         (conv3): Conv2D(256 -> 512, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (1): Residual(
#         (conv1): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=512)
#         (conv2): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn2): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=512)
#       )
#     )
#     (5): Sequential(
#       (0): AvgPool2D(size=(3, 3), stride=(3, 3), padding=(0, 0), ceil_mode=False)
#       (1): Dense(512 -> 10, linear)
#     )
#   )
# )

# %%
# 读取数据
import sys
sys.path.append('..')
import utils
from mxnet import autograd
from mxnet import gluon
from mxnet import nd
from mxnet import image
from mxnet import init

batch_size = 128
resize=224

ctx = utils.try_gpu(1)
net = ResNet(10, verbose=False)
net.initialize(ctx=ctx, init=init.Xavier())

def transform(data, label):
#     print(data.shape)   # (28, 28, 1)
#     print(label.shape)    # (1,)
# change data from batch x height x width x channel
# to batch x channel x height x width
#     return nd.transpose(data.astype('float32'), (0,3,1,2))/255, label.astype('float32')
    data = image.imresize(data, resize, resize)
#     data = new_data
            
    return nd.transpose(data.astype('float32'), (2,0,1))/255, label.astype('float32')
#     return data.astype('float32') / 255, label.astype('float32')
mnist_train = gluon.data.vision.FashionMNIST(train=True, transform=transform)
mnist_test = gluon.data.vision.FashionMNIST(train=False, transform=transform)
train_data = gluon.data.DataLoader(mnist_train, batch_size, shuffle=True)
test_data = gluon.data.DataLoader(mnist_test, batch_size, shuffle=False)

# %%
# 训练
import time
from mxnet import gluon

softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()

trainable_params = net.collect_params()
print(trainable_params)

trainer = gluon.Trainer(trainable_params, 'sgd', {
    'learning_rate': 0.05
})

for epoch in range(10):
    time_start = time.time()
    train_loss = 0.
    train_acc = 0.
    for data, label in train_data:
        label = label.as_in_context(ctx)
        with autograd.record():
            output = net(data.as_in_context(ctx))
            loss = softmax_cross_entropy(output, label)
        loss.backward()
        trainer.step(batch_size)

        train_loss += nd.mean(loss).asscalar()
        train_acc += utils.accuracy(output, label)
    test_acc = utils.evaluate_accuracy(test_data, net, ctx)
    print("Epoch %d. Loss: %.4f, Train acc %.4f, Test acc %.4f, Time %.0f sec" % (
        epoch, train_loss/len(train_data),
        train_acc/len(train_data), test_acc, time.time() - time_start))
# Out:
# resnet1_ (
#   Parameter resnet1_conv0_weight (shape=(64, 0, 7, 7), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv0_bias (shape=(64,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv1_weight (shape=(64, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv1_bias (shape=(64,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm0_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm0_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm0_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm0_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv2_weight (shape=(64, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv2_bias (shape=(64,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm1_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm1_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm1_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm1_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv3_weight (shape=(64, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv3_bias (shape=(64,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm2_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm2_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm2_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm2_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv4_weight (shape=(64, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv4_bias (shape=(64,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm3_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm3_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm3_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm3_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv5_weight (shape=(128, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv5_bias (shape=(128,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm4_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm4_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm4_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm4_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv6_weight (shape=(128, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv6_bias (shape=(128,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm5_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm5_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm5_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm5_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv7_weight (shape=(128, 0, 1, 1), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv7_bias (shape=(128,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv8_weight (shape=(128, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv8_bias (shape=(128,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm6_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm6_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm6_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm6_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv9_weight (shape=(128, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv9_bias (shape=(128,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm7_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm7_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm7_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm7_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv10_weight (shape=(256, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv10_bias (shape=(256,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm8_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm8_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm8_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm8_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv11_weight (shape=(256, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv11_bias (shape=(256,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm9_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm9_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm9_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm9_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv12_weight (shape=(256, 0, 1, 1), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv12_bias (shape=(256,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv13_weight (shape=(256, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv13_bias (shape=(256,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm10_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm10_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm10_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm10_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv14_weight (shape=(256, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv14_bias (shape=(256,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm11_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm11_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm11_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm11_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv15_weight (shape=(512, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv15_bias (shape=(512,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm12_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm12_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm12_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm12_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv16_weight (shape=(512, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv16_bias (shape=(512,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm13_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm13_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm13_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm13_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv17_weight (shape=(512, 0, 1, 1), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv17_bias (shape=(512,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv18_weight (shape=(512, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv18_bias (shape=(512,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm14_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm14_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm14_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm14_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv19_weight (shape=(512, 0, 3, 3), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_conv19_bias (shape=(512,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm15_gamma (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm15_beta (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm15_running_mean (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_batchnorm15_running_var (shape=(0,), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_dense0_weight (shape=(10, 0), dtype=<class 'numpy.float32'>)
#   Parameter resnet1_dense0_bias (shape=(10,), dtype=<class 'numpy.float32'>)
# )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b94239184c33> in <module>()
#      24         trainer.step(batch_size)
#      25
# ---> 26         train_loss += nd.mean(loss).asscalar()
#      27         train_acc += utils.accuracy(output, label)
#      28     test_acc = utils.evaluate_accuracy(test_data, net, ctx)
#
# ~/anaconda3/envs/learning/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asscalar(self)
#    1892         if self.shape != (1,):
#    1893             raise ValueError("The current array is not a scalar")
# -> 1894         return self.asnumpy()[0]
#    1895
#    1896     def astype(self, dtype, copy=True):
#
# ~/anaconda3/envs/learning/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asnumpy(self)
#    1874             self.handle,
#    1875             data.ctypes.data_as(ctypes.c_void_p),
# -> 1876             ctypes.c_size_t(data.size)))
#    1877         return data
#    1878
#
# KeyboardInterrupt:
